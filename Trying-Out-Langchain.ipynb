# %%
from dotenv import load_dotenv
import os

load_dotenv()

from langchain.chat_models import init_chat_model

model = init_chat_model("gpt-3.5-turbo", model_provider="openai")

# %%
model.invoke("Hi there Gpt, you know who I am?")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.invoke("Hi there Gpt, you know who I am?")
#
# File ~/miniconda3/envs/ML/lib/python3.12/site-packages/langchain_core/language_models/chat_models.py:307, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     296 def invoke(
#     297     self,
#     298     input: LanguageModelInput,
#    (...)
#     302     **kwargs: Any,
#     303 ) -> BaseMessage:
#     304     config = ensure_config(config)
#     305     return cast(
#     306         ChatGeneration,
# --> 307         self.generate_prompt(
#     308             [self._convert_input(input)],
#     309             stop=stop,
#     310             callbacks=config.get("callbacks"),
#     311             tags=config.get("tags"),
#     312             metadata=config.get("metadata"),
# ...
